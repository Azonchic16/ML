# %%
import pandas as pd
import numpy as np
from MyTreeReg_copy import MyTreeReg
from sklearn.datasets import load_diabetes
X = load_diabetes()
df = pd.DataFrame(X['data'], columns=X['feature_names'])
y = X['target']
lst = [(1,1,2), (3,2,5), (5,100,10), (4,50,17), (10,40,21), (15,35,30)]
lst = [lst[3]]

# %%
for max_depth, min_samples_split, max_leafs in lst:
    model = MyTreeReg(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs)
    model.fit(df, y)
    print(round(model.leafs_sum, 6))
    print(model.leafs_cnt)
# Out:
# /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:80: RuntimeWarning: Mean of empty slice.
#   return  np.sum((y - y.mean()) ** 2) / N
# /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:80: RuntimeWarning: invalid value encountered in scalar divide
#   return  np.sum((y - y.mean()) ** 2) / N
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 for max_depth, min_samples_split, max_leafs in lst:
#       2     model = MyTreeReg(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs)
# ----> 3     model.fit(df, y)
#       4     print(round(model.leafs_sum, 6))
#       5     print(model.leafs_cnt)
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:233, in MyTreeReg.fit(self, X, y)
#     230 self.names = X.columns.values.tolist()
#     231 # self.get_split_values_or_bins(X)
#     232 # self.fi.update({col: 0 for col in X.columns.values})
# --> 233 self.build_tree(X)
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:170, in MyTreeReg.build_tree(self, X)
#     168     self.potential_leafs += 1
#     169     # self.fi[col_name] += self.compute_feature_importance(X, X_left, X_right)
# --> 170     self.build_tree(X_left)
#     171 if not self.curr.left:
#     172     y = self.y[X.index]
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:184, in MyTreeReg.build_tree(self, X)
#     182     self.depth += 1
#     183     self.potential_leafs += 1
# --> 184     self.build_tree(X_left)
#     185 else: #  лист
#     186     # print('Зашел в левый лист')
#     187     self.curr.left = Node(('leaf_left', y.mean()))
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:184, in MyTreeReg.build_tree(self, X)
#     182     self.depth += 1
#     183     self.potential_leafs += 1
# --> 184     self.build_tree(X_left)
#     185 else: #  лист
#     186     # print('Зашел в левый лист')
#     187     self.curr.left = Node(('leaf_left', y.mean()))
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:184, in MyTreeReg.build_tree(self, X)
#     182     self.depth += 1
#     183     self.potential_leafs += 1
# --> 184     self.build_tree(X_left)
#     185 else: #  лист
#     186     # print('Зашел в левый лист')
#     187     self.curr.left = Node(('leaf_left', y.mean()))
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:193, in MyTreeReg.build_tree(self, X)
#     191         self.leafs_cnt += 1
#     192         self.potential_leafs -= 1
# --> 193         self.build_tree(self.curr.df)
#     194 elif self.curr.left and not self.curr.right:
#     195     X_curr = self.curr.df.loc[self.curr.df[self.curr.value[0]] > self.curr.value[1]]
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:197, in MyTreeReg.build_tree(self, X)
#     195 X_curr = self.curr.df.loc[self.curr.df[self.curr.value[0]] > self.curr.value[1]]
#     196 y_r = self.y[X_curr.index]
# --> 197 col_name, split_value = self.get_best_split(X_curr, y_r)
#     198 if not self.is_leaf(y_r) and col_name:
#     199     self.curr.right = Node((col_name, split_value))
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg_copy.py:138, in MyTreeReg.get_best_split(self, X, y)
#     117             col_name = min(col_name, self.names[i])
#     118         # d.loc[len(d.index)] = [names[i], feature_unique_mean[k], ig]
#     119 # else:
#     120 #     for name in names:
#    (...)
#     136 #             d.loc[len(d.index)] = [name, k, ig]
#     137 # d = d.sort_values(by=['ig', 'col_name'], ascending=[False, True])
# --> 138 return col_name, split_value
#
# UnboundLocalError: local variable 'col_name' referenced before assignment

# %%
model.tree.print_tree()
# Out:
# └── s5 > -0.0037611760063045703
#     ├── bmi > 0.0061888847138220964
#     │   ├── s3 > 0.02102781591949656
#     │   │   ├── s1 > 0.09106491880169407
#     │   │   │   ├── leaf_left = 108.80459770114942

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]
