# %%
import pandas as pd
import numpy as np
from MyTreeReg import MyTreeReg
from sklearn.datasets import load_diabetes
X = load_diabetes()
df = pd.DataFrame(X['data'], columns=X['feature_names'])
y = X['target']
lst = [(1,1,2,8), (3,2,5,None), (5,100,10, 4), (4,50,17,16), (10,40,21, 21), (15,35,30,30)]
# lst = [lst[0]]

# %%
for max_depth, min_samples_split, max_leafs, bins in lst:
    model = MyTreeReg(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs, bins=bins)
    model.fit(df, y)
    print(f'{model.leafs_cnt}      {round(model.leafs_sum, 6)}')
# Out:
# 2      324.685749
# 5      813.992098
# 10      1678.172395
# 12      2031.142507
# 21      3256.703317
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 for max_depth, min_samples_split, max_leafs, bins in lst:
#       2     model = MyTreeReg(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs, bins=bins)
# ----> 3     model.fit(df, y)
#       4     print(f'{model.leafs_cnt}      {round(model.leafs_sum, 6)}')
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg.py:263, in MyTreeReg.fit(self, X, y)
#     261 self.get_split_values_or_bins(X)
#     262 # self.fi.update({col: 0 for col in X.columns.values})
# --> 263 self.build_tree(X)
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeReg.py:199, in MyTreeReg.build_tree(self, X)
#     197     self.potential_leafs += 1
# ...

# %%
model.tree.print_tree()
# Out:
# └── s5 > -0.0037611760063045703
#     ├── bmi > 0.0061888847138220964
#     │   ├── s3 > 0.02102781591949656
#     │   │   ├── s1 > 0.06310082451524143
#     │   │   │   ├── sex > 0.003019241116414738
#     │   │   │   │   ├── bp > -0.03493465558747611
#     │   │   │   │   │   ├── leaf_left = 100.42857142857143
#     │   │   │   │   │   ├── leaf_right = 140.33333333333334
#     │   │   │   │   ├── s6 > -0.02800139244688993
#     │   │   │   │   │   ├── leaf_left = 74.22222222222223
#     │   │   │   │   │   ├── leaf_right = 107.57142857142857
#     │   │   │   ├── leaf_right = 241.5
#     │   │   ├── sex > 0.003019241116414738
#     │   │   │   ├── bmi > -0.06279108801454907
#     │   │   │   │   ├── leaf_left = 68.57142857142857
#     │   │   │   │   ├── bp > 0.025315236489885963
#     │   │   │   │   │   ├── bmi > -0.013211732616032285
#     │   │   │   │   │   │   ├── s5 > -0.011400050993453053
#     │   │   │   │   │   │   │   ├── age > -0.04002367026349452
# ...

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df = pd.read_csv('data/model.curr.df.csv')
l = df.loc[df['s3'] <= 0.02102781591949656]
r = df.loc[df['s3'] > 0.02102781591949656]
l
# Out:
#          age       sex       bmi        bp        s1        s2        s3  \
# 0   0.001751  0.050680 -0.057941 -0.043542 -0.096510 -0.047034 -0.098625
# 1   0.038076  0.050680 -0.018062  0.066629 -0.051103 -0.016658 -0.076536
# 2   0.078034  0.050680 -0.024529 -0.042406  0.006687  0.052861 -0.069172
# 3   0.067136  0.050680 -0.014828  0.058608 -0.059359 -0.034508 -0.061809
# 4  -0.060003  0.050680 -0.010517 -0.014863 -0.049727 -0.023547 -0.058127
# ..       ...       ...       ...       ...       ...       ...       ...
# 82 -0.016412 -0.044642 -0.013751  0.132044 -0.009825 -0.003819  0.019187
# 83 -0.023677 -0.044642 -0.069797 -0.064199 -0.059359 -0.050478  0.019187
# 84 -0.085430  0.050680 -0.030996 -0.022885 -0.063487 -0.054236  0.019187
# 85 -0.012780  0.050680 -0.055785 -0.002228 -0.027712 -0.029184  0.019187
# 86 -0.016412 -0.044642 -0.052552 -0.033213 -0.044223 -0.036387  0.019187
#
#           s4        s5        s6
# 0   0.034309 -0.061176 -0.071494
# ...

# %%
a = np.array([3])
a[1:] + a[:-1]
# Out:
# array([], dtype=int64)
