# %%
import pandas as pd
import numpy as np
from MyTreeClf import MyTreeClf
df = pd.read_csv('data/BankNote_Authentication.xls')
y = df['class']
del df['class']
lst = [(1,1,2,8, 'gini'), (3,2,5,None,'gini'), (5,200,10,4,'entropy'), (4,100,17,16,'gini'), (10,40,21,10,'gini'), (15,20,30,6,'gini')]
for max_depth, min_samples_split, max_leafs, bins, criterion in lst:
    model = MyTreeClf(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs, bins=bins, criterion=criterion)
    model.fit(df, y)
    print(round(model.leafs_sum, 6))
    print(model.leafs_cnt)
    print(model.fi)
# Out:
# 0.981148
# 2
# {'variance': 0.2307416940473953, 'skewness': 0, 'curtosis': 0, 'entropy': 0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 for max_depth, min_samples_split, max_leafs, bins, criterion in lst:
#       9     model = MyTreeClf(max_depth=max_depth, min_samples_split=min_samples_split, max_leafs=max_leafs, bins=bins, criterion=criterion)
# ---> 10     model.fit(df, y)
#      11     print(round(model.leafs_sum, 6))
#      12     print(model.leafs_cnt)
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeClf.py:232, in MyTreeClf.fit(self, X, y)
#     230 self.get_split_values_or_bins(X)
#     231 self.fi.update({col: 0 for col in X.columns.values})
# --> 232 self.build_tree(X)
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeClf.py:161, in MyTreeClf.build_tree(self, X)
#     159 if not self.tree.root:
#     160     y = self.y[X.index]
# --> 161     col_name, split_value = self.get_best_split(X, y)
#     162     self.tree.root = Node((col_name, split_value))
#     163     self.tree.root.df = X
#
# File /media/aziz16/Новый том/my_project_dir/ML_algo_stepic_course/MyTreeClf.py:116, in MyTreeClf.get_best_split(self, X, y)
#     114             S2 = self.entropy_gini(N2, c_n_r)
#     115             ig = S0 - (N1 / N) * S1 - (N2 / N) * S2
# --> 116             d.loc[len(d.index)] = [names[i], feature_unique_mean[k], ig]
#     117 else:
#     118     for name in names:
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1929     indexer, missing = convert_missing_indexer(indexer)
#    1931     if missing:
# -> 1932         self._setitem_with_indexer_missing(indexer, value)
#    1933         return
#    1935 if name == "loc":
#    1936     # must come after setting of missing
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/indexing.py:2328, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2326     self.obj._mgr = df._mgr
#    2327 else:
# -> 2328     self.obj._mgr = self.obj._append(value)._mgr
#    2329 self.obj._maybe_update_cacher(clear=True)
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/frame.py:10554, in DataFrame._append(self, other, ignore_index, verify_integrity, sort)
#   10551     row_df = other.to_frame().T
#   10552     # infer_objects is needed for
#   10553     #  test_append_empty_frame_to_series_with_dateutil_tz
# > 10554     other = row_df.infer_objects(copy=False).rename_axis(
#   10555         index.names, copy=False
#   10556     )
#   10557 elif isinstance(other, list):
#   10558     if not other:
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/generic.py:6888, in NDFrame.infer_objects(self, copy)
#    6831 @final
#    6832 def infer_objects(self, copy: bool_t | None = None) -> Self:
#    6833     """
#    6834     Attempt to infer better dtypes for object columns.
#    6835
#    (...)
#    6886     dtype: object
#    6887     """
# -> 6888     new_mgr = self._mgr.convert(copy=copy)
#    6889     res = self._constructor_from_mgr(new_mgr, axes=new_mgr.axes)
#    6890     return res.__finalize__(self, method="infer_objects")
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:447, in BaseBlockManager.convert(self, copy)
#     444 elif using_copy_on_write():
#     445     copy = False
# --> 447 return self.apply("convert", copy=copy, using_cow=using_copy_on_write())
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:633, in Block.convert(self, copy, using_cow)
#     622 @final
#     623 def convert(
#     624     self,
#    (...)
#     627     using_cow: bool = False,
#     628 ) -> list[Block]:
#     629     """
#     630     Attempt to coerce any object types to better types. Return a copy
#     631     of the block (if copy = True).
#     632     """
# --> 633     if not self.is_object:
#     634         if not copy and using_cow:
#     635             return [self.copy(deep=False)]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /media/aziz16/Новый том/my_project_dir/venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:209, in Block.is_object(self)
#     204     dtype = self.dtype
#     205     return not isinstance(dtype, ExtensionDtype) or isinstance(
#     206         dtype, DatetimeTZDtype
#     207     )
# --> 209 @final
#     210 @cache_readonly
#     211 def is_object(self) -> bool:
#     212     return self.values.dtype == _dtype_obj
#     214 @final
#     215 @cache_readonly
#     216 def is_extension(self) -> bool:
#
# KeyboardInterrupt:
