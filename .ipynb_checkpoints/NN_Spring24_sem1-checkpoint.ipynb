# %%
# для нейронной сети
import torch
import torch.nn as nn
import torch.optim as optim
# для графиков
import matplotlib.pyplot as plt

# %%
# реализация сети
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = nn.Linear(2, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc(x)
        x = self.sigmoid(x)
        return x

# %%
def init_and_train(inputs, targets, epochs):
    net = Net()

    inputs = torch.tensor(inputs, dtype=torch.float32)
    targets = torch.tensor(targets, dtype=torch.float32)

    criterion = nn.MSELoss() # функция ошибки
    optimizer = optim.SGD(net.parameters(), lr=0.1) # метод оптимизации

    loss_values = []

    print('Начальные коэффициенты')
    for name, param in net.named_parameters():
      print(f'{name}: {param}')

    for epoch in range(epochs):
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        loss_values.append(loss.item())



    plt.plot(range(epochs), loss_values)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training Loss")
    plt.show()

    test_outputs = net(inputs)
    print(f'Results:\n {test_outputs.round().detach().numpy()}')

    print('Коэффициенты после обучения')
    for name, param in net.named_parameters():
      print(f'{name}: {param}')

# %%
# конъюнкция
init_and_train(inputs = [[0, 0], [0, 1], [1, 0], [1, 1]], targets = [[0], [0], [0], [1]], epochs = 1000)
# Out:
# Начальные коэффициенты
# fc.weight: Parameter containing:
# tensor([[-0.1149,  0.1411]], requires_grad=True)
# fc.bias: Parameter containing:
# tensor([-0.1215], requires_grad=True)
# Results:
#  [[0.]
#  [0.]
#  [0.]
#  [1.]]
# Коэффициенты после обучения
# fc.weight: Parameter containing:
# tensor([[1.8221, 1.8299]], requires_grad=True)
# fc.bias: Parameter containing:
# tensor([-2.8965], requires_grad=True)

# %%
# дизъюнкция
init_and_train(inputs = [[0, 0], [0, 1], [1, 0], [1, 1]], targets = [[0], [1], [1], [1]], epochs = 1000)
# Out:
# Начальные коэффициенты
# fc.weight: Parameter containing:
# tensor([[0.0661, 0.3365]], requires_grad=True)
# fc.bias: Parameter containing:
# tensor([-0.0486], requires_grad=True)
# Results:
#  [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Коэффициенты после обучения
# fc.weight: Parameter containing:
# tensor([[2.4490, 2.4723]], requires_grad=True)
# fc.bias: Parameter containing:
# tensor([-0.8653], requires_grad=True)

# %%
import matplotlib.pyplot as plt
x = np.linspace(-5,5,100)
plt.plot(x, np.sin(np.abs(5 * x)) * np.exp(-np.abs.exp(x)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 import matplotlib.pyplot as plt
#       2 x = np.linspace(-5,5,100)
# ----> 3 plt.plot(x, np.sin(np.abs(5 * x)) * np.exp(-absnp.abs(x)))
#
# NameError: name 'absnp' is not defined
